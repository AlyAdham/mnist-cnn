# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyAdham/mnist-cnn/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Load and transform the dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# Define the CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize model, loss function, and optimizer
model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 5
for epoch in range(epochs):
    for images, labels in trainloader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")

print("Training complete!")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 41.0MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.23MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 10.7MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.04MB/s]
# Epoch 1, Loss: 0.12823843955993652
# Epoch 2, Loss: 0.0016514729941263795
# Epoch 3, Loss: 0.00955398939549923
# Epoch 4, Loss: 0.010969316586852074
# Epoch 5, Loss: 0.0010438949102535844
# Training complete!

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Load and transform the dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# Define the CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize model, loss function, and optimizer
model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 5
losses = []  # List to store loss values

for epoch in range(epochs):
    running_loss = 0.0
    for images, labels in trainloader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_loss = running_loss / len(trainloader)  # Calculate average loss per epoch
    losses.append(avg_loss)  # Store loss for plotting
    print(f"Epoch {epoch+1}, Loss: {avg_loss}")

print("Training complete!")

# Plot the loss curve
plt.plot(losses, marker='o', linestyle='-', color='b', label="Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Over Time")
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1, Loss: 0.1444062872741149
# Epoch 2, Loss: 0.041747797150854894
# Epoch 3, Loss: 0.029605264514513407
# Epoch 4, Loss: 0.021050172246883866
# Epoch 5, Loss: 0.017377770319121823
# Training complete!

# %%
# Set the model to evaluation mode
model.eval()

# Get a batch of test images
dataiter = iter(testloader)
images, labels = next(dataiter)

# Get model predictions
outputs = model(images)
_, predicted = torch.max(outputs, 1)  # Get the predicted class (digit)

# Show the images and predictions
fig, axes = plt.subplots(1, 6, figsize=(12, 4))
for i in range(6):  # Show first 6 images
    ax = axes[i]
    img = images[i].squeeze().numpy()  # Convert tensor to numpy array
    ax.imshow(img, cmap='gray')  # Show the image in grayscale
    ax.set_title(f"Predicted: {predicted[i].item()}")
    ax.axis('off')

plt.show()

# Print actual labels vs. predicted labels
print("Actual labels:   ", labels[:6].tolist())
print("Predicted labels:", predicted[:6].tolist())
# Out:
# Actual labels:    [7, 2, 1, 0, 4, 1]
# Predicted labels: [7, 2, 1, 0, 4, 1]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Load and transform the dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# Define the CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize model, loss function, and optimizer
model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 5
losses = []  # Store loss for visualization

for epoch in range(epochs):
    epoch_loss = 0
    for images, labels in trainloader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    avg_loss = epoch_loss / len(trainloader)
    losses.append(avg_loss)
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")

print("Training complete!")

# Function to calculate model accuracy
def calculate_accuracy(model, dataloader):
    model.eval()  # Set model to evaluation mode
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in dataloader:
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# Compute and print accuracy
test_accuracy = calculate_accuracy(model, testloader)
print(f"Test Accuracy: {test_accuracy:.2f}%")

# Plot training loss over epochs
plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Over Time")
plt.show()

# Set the model to evaluation mode
model.eval()

# Get a batch of test images
dataiter = iter(testloader)
images, labels = next(dataiter)

# Get model predictions
outputs = model(images)
_, predicted = torch.max(outputs, 1)

# Show the images and predictions
fig, axes = plt.subplots(1, 6, figsize=(12, 4))
for i in range(6):  # Show first 6 images
    ax = axes[i]
    img = images[i].squeeze().numpy()
    ax.imshow(img, cmap='gray')
    ax.set_title(f"Predicted: {predicted[i].item()}")
    ax.axis('off')

plt.show()

# Print actual labels vs. predicted labels
print("Actual labels:   ", labels[:6].tolist())
print("Predicted labels:", predicted[:6].tolist())
# Out:
# Epoch 1, Loss: 0.1587
# Epoch 2, Loss: 0.0454
# Epoch 3, Loss: 0.0315
# Epoch 4, Loss: 0.0250
# Epoch 5, Loss: 0.0168
# Training complete!
# Test Accuracy: 99.01%
# Actual labels:    [7, 2, 1, 0, 4, 1]
# Predicted labels: [7, 2, 1, 0, 4, 1]
